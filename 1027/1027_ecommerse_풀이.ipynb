# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ecommerse.csv')

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
# 1. 
df['Purchase Price']
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %%
df['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
# 2. 
df['Language'].value_counts()
# Out:
# de    1155
# ru    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: Language, dtype: int64

# %%
df[df['Language'].str.upper() == 'EN'] # 원본에 저장하지 말기. 임시로만 사용할 것
# Out:
#                                                 Address    Lot AM or PM  \
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# 26          5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND       AM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# ...                                                 ...    ...      ...
# 9961        714 Joshua Ridges\nCarpenterville, NJ 37418  84 rK       PM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK       PM
#
#                                            Browser Info  \
# ...

# %%
len(df[df['Language'].str.upper() == 'EN'])
# Out:
# 1098

# %%
#
user_in = input('언어를 입력하세요.')

# %%
len(df[df['Language'].str.lower() == user_in.lower()])

# %%
#3.
df['Job'].unique()
# Out:
# array(['Scientist, product/process development', 'Drilling engineer',
#        'Customer service manager', 'Fine artist', 'Fish farm manager',
#        'Dancer', 'Event organiser', 'Financial manager',
#        'Forensic scientist', 'Development worker, community',
#        'Diagnostic radiographer', 'Surveyor, quantity',
#        'Accountant, chartered public finance', 'Acupuncturist',
#        'Retail manager', 'Therapist, art', 'Designer, jewellery',
#        'Photographer', 'Designer, interior/spatial',
#        'Public relations officer', 'Presenter, broadcasting',
#        'Field seismologist', 'Musician',
#        'Training and development officer', "Barrister's clerk",
#        'Careers adviser', 'Scientist, research (life sciences)',
#        'Recycling officer', 'Fisheries officer', 'Sales executive',
#        'Civil Service fast streamer', 'Theatre stage manager',
#        'Therapist, music', 'Lecturer, further education',
# ...

# %%
len(df['Job'].unique())
# Out:
# 623

# %%
#4
df[['Job', 'Purchase Price']]
# Out:
#                                          Job  Purchase Price
# 0     Scientist, product/process development           98.14
# 1                          Drilling engineer           70.73
# 2                   Customer service manager            0.95
# 3                          Drilling engineer           78.04
# 4                                Fine artist           77.82
# ...                                      ...             ...
# 9995                              Printmaker           82.21
# 9996                         Energy engineer           25.63
# 9997                      Veterinary surgeon           83.98
# 9998                Local government officer           38.84
# 9999                  Embryologist, clinical           67.59
#
# [10000 rows x 2 columns]

# %%
df.groupby('Job')['Purchase Price'].sum()
# Out:
# Job
# Academic librarian                   527.47
# Accommodation manager                629.65
# Accountant, chartered               1051.31
# Accountant, chartered certified     1043.01
# Accountant, chartered management    1036.24
#                                      ...
# Water quality scientist              837.47
# Web designer                        1195.29
# Wellsite geologist                  1231.42
# Writer                               448.63
# Youth worker                         729.24
# Name: Purchase Price, Length: 623, dtype: float64

# %%
df.groupby('Job')['Purchase Price'].sum().sort_values(ascending = False)
# Out:
# Job
# Dietitian                      1605.30
# Lawyer                         1603.85
# Purchasing manager             1577.97
# Therapist, art                 1526.31
# Clinical cytogeneticist        1495.92
#                                 ...
# Music therapist                 327.50
# Actuary                         262.72
# Information systems manager     241.42
# Marketing executive             234.08
# Art gallery manager             219.05
# Name: Purchase Price, Length: 623, dtype: float64

# %%
df.groupby('Job')['Purchase Price'].sum().sort_values(ascending = False).head(1)
# Out:
# Job
# Dietitian    1605.3
# Name: Purchase Price, dtype: float64

# %%
df.groupby('Job')['Purchase Price'].sum().sort_values(ascending = False).index[0]
# Out:
# 'Dietitian'

# %%
df.groupby('Job')['Purchase Price'].sum().sort_values(ascending = False).values[0]
# Out:
# 1605.3

# %%
df.groupby('Job')['Purchase Price'].sum().sort_values(ascending = True)
# Out:
# Job
# Art gallery manager             219.05
# Marketing executive             234.08
# Information systems manager     241.42
# Actuary                         262.72
# Music therapist                 327.50
#                                 ...
# Clinical cytogeneticist        1495.92
# Therapist, art                 1526.31
# Purchasing manager             1577.97
# Lawyer                         1603.85
# Dietitian                      1605.30
# Name: Purchase Price, Length: 623, dtype: float64

# %%
df.groupby('Job')['Purchase Price'].sum().sort_values(ascending = True).head(1)
# Out:
# Job
# Art gallery manager    219.05
# Name: Purchase Price, dtype: float64

# %%
df.groupby('Job')['Purchase Price'].sum().sort_values(ascending = True).index[0]
# Out:
# 'Art gallery manager'

# %%
df.groupby('Job')['Purchase Price'].sum().sort_values(ascending = True).values[0]
# Out:
# 219.05

# %%
#6

df['Job'].value_counts().head(1)
# Out:
# Interior and spatial designer    31
# Name: Job, dtype: int64

# %%
#7

df['Email']
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
df['Email'].str.lower()
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
df['Email'].str.upper()
# Out:
# 0                    PDUNLAP@YAHOO.COM
# 1                   ANTHONY41@REED.COM
# 2       AMYMILLER@MORALES-HARRISON.COM
# 3          BRENT16@OLSON-ROBINSON.INFO
# 4          CHRISTOPHERWRIGHT@GMAIL.COM
#                      ...
# 9995            ISCOTT@WADE-GARNER.COM
# 9996                MARY85@HOTMAIL.COM
# 9997                 TYLER16@GMAIL.COM
# 9998           ELIZABETHMOORE@REID.NET
# 9999             RACHELFORD@VAUGHN.COM
# Name: Email, Length: 10000, dtype: object

# %%
df[df['Email'].str.lower() == 'bondellen@williams-garza.com'.lower()]['Purchase Price'].values[0]
# Out:
# 77.88

# %%
#8

df['CC Provider'].unique()
# Out:
# array(['JCB 16 digit', 'Mastercard', 'Discover',
#        'Diners Club / Carte Blanche', 'VISA 16 digit', 'VISA 13 digit',
#        'American Express', 'Voyager', 'JCB 15 digit', 'Maestro'],
#       dtype=object)

# %%
df['CC Provider'].str.lower() == 'Mastercard'.lower()
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: CC Provider, Length: 10000, dtype: bool

# %%
df[(df['CC Provider'].str.lower() == 'Mastercard'.lower()) & (df['Purchase Price'] >= 50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
len(df[(df['CC Provider'].str.lower() == 'Mastercard'.lower())
       & (df['Purchase Price'] >= 50)])
# Out:
# 405

# %%
#9 Browser info == user agent 

len(df[(df['Browser Info'].str.lower()).str.contains('Windows'.lower())])
# Out:
# 4994

# %%
for os in ['window', 'linux', 'mac'] :
    p = len(df[(df['Browser Info'].str.lower()).str.contains(os)])
    print(os, p/len(df)*100)
# Out:
# window 49.94
# linux 23.22
# mac 26.840000000000003

# %%
for os in ['window', 'linux', 'mac'] :
    p = len(df[(df['Browser Info'].str.lower()).str.contains(os)])
    print(f'%6s %.2f'%(os, p/len(df)*100))
    
# 6칸, 소수점 2자리
# Out:
# window 49.94
#  linux 23.22
#    mac 26.84
