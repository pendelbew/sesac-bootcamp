# %%
import pandas as pd
import numpy as np

# %%
ecommerse = pd.read_csv('ecommerse.csv')

# %%
ecommerse = pd.DataFrame(ecommerse)

# %%
ecommerse
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecommerse.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
# 총 구매 금액의 평균

# %%
ecommerse['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
# 웹사이트 언어로 영어를 쓰는 사람의 수

# %%
ecommerse['Language'].value_counts()
# Out:
# de    1155
# ru    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: Language, dtype: int64

# %%
len(ecommerse[ecommerse['Language'] == 'en'])
# Out:
# 1098

# %%
len(ecommerse[ecommerse['Language'].str.lower() == 'en'])
# Out:
# 1098

# %%
# 고객들의 직업 수

# %%
ecommerse['Job'].unique()
# Out:
# array(['Scientist, product/process development', 'Drilling engineer',
#        'Customer service manager', 'Fine artist', 'Fish farm manager',
#        'Dancer', 'Event organiser', 'Financial manager',
#        'Forensic scientist', 'Development worker, community',
#        'Diagnostic radiographer', 'Surveyor, quantity',
#        'Accountant, chartered public finance', 'Acupuncturist',
#        'Retail manager', 'Therapist, art', 'Designer, jewellery',
#        'Photographer', 'Designer, interior/spatial',
#        'Public relations officer', 'Presenter, broadcasting',
#        'Field seismologist', 'Musician',
#        'Training and development officer', "Barrister's clerk",
#        'Careers adviser', 'Scientist, research (life sciences)',
#        'Recycling officer', 'Fisheries officer', 'Sales executive',
#        'Civil Service fast streamer', 'Theatre stage manager',
#        'Therapist, music', 'Lecturer, further education',
# ...

# %%
len(ecommerse['Job'].unique())
# Out:
# 623

# %%
# 직업별 구매 금액의 평균이 가장 높은 직업은?

# %%
# 직업별 구매 금액의 평균이 가장 낮은 직업은?

# %%
ecommerse.groupby('Job')

# %%
((ecommerse.groupby('Job')['Purchase Price'].mean()).sort_values()).head(1)
# Out:
# Job
# Marketing executive    26.008889
# Name: Purchase Price, dtype: float64

# %%
((ecommerse.groupby('Job')['Purchase Price'].mean()).sort_values()).tail(1)
# Out:
# Job
# Trade mark attorney    73.802727
# Name: Purchase Price, dtype: float64

# %%
# 직업별 구매 금액의 합이 가장 높은 / 낮은 직업

# %%
ecommerse.groupby('Job')

# %%
(ecommerse.groupby('Job')['Purchase Price'].sum()).sort_values()
# Out:
# Job
# Art gallery manager             219.05
# Marketing executive             234.08
# Information systems manager     241.42
# Actuary                         262.72
# Music therapist                 327.50
#                                 ...
# Clinical cytogeneticist        1495.92
# Therapist, art                 1526.31
# Purchasing manager             1577.97
# Lawyer                         1603.85
# Dietitian                      1605.30
# Name: Purchase Price, Length: 623, dtype: float64

# %%
((ecommerse.groupby('Job')['Purchase Price'].sum().max()))
# Out:
# 1605.3

# %%
# 가장 많은 구매(횟수)를 한 직업은?

# %%
((ecommerse['Job'].value_counts()).sort_values())
# Out:
# Investment analyst                5
# Information systems manager       5
# Editor, film/video                6
# Actuary                           6
# Stage manager                     7
#                                  ..
# Designer, jewellery              27
# Purchasing manager               27
# Social researcher                28
# Lawyer                           30
# Interior and spatial designer    31
# Name: Job, Length: 623, dtype: int64

# %%
((ecommerse['Job'].value_counts()).sort_values()).tail(1)
# Out:
# Interior and spatial designer    31
# Name: Job, dtype: int64

# %%
# bondellen@williams-garza.com 메일 주소를 가진 사용자의 구매금액은?

# %%
ecommerse[ecommerse['Email'] == 'bondellen@williams-garza.com']
# Out:
#                                                 Address    Lot AM or PM  \
# 1234  2470 Maria Manors Suite 185\nJoneshaven, MN 87251  82 UX       PM
#
#                                            Browser Info  \
# 1234  Mozilla/5.0 (X11; Linux x86_64; rv:1.9.5.20) G...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 1234  Cole, King and Bowers  4926535242672853       09/21               188
#
#            CC Provider                         Email  \
# 1234  American Express  bondellen@williams-garza.com
#
#                                     Job    IP Address Language  Purchase Price
# 1234  Planning and development surveyor  159.182.3.50       ru           77.88

# %%
ecommerse[ecommerse['Email'].str.lower() == 'bondellen@williams-garza.com']['Purchase Price']
# Out:
# 1234    77.88
# Name: Purchase Price, dtype: float64

# %%
# MasterCard 를 사용했으며 50달러 이상 구매한 사용자는 몇 명?

# %%
(ecommerse['CC Provider'] == 'Mastercard')
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: CC Provider, Length: 10000, dtype: bool

# %%
(ecommerse['Purchase Price'] >= 50)
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 9995     True
# 9996    False
# 9997     True
# 9998    False
# 9999     True
# Name: Purchase Price, Length: 10000, dtype: bool

# %%
ecommerse[(ecommerse['CC Provider'].str.lower() == 'Mastercard'.lower()) & (ecommerse['Purchase Price'] >= 50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
len(ecommerse[(ecommerse['CC Provider'].str.lower() == 'Mastercard'.lower()) & (ecommerse['Purchase Price'] >= 50)])
# Out:
# 405

# %%
# 윈도우를 사용하는 사용자는 몇 명?

# %%
len(ecommerse[(ecommerse['Browser Info'].str.lower()).str.contains('windows')])
# Out:
# 4994

# %%
ecommerse[(ecommerse['Browser Info'].str.contains('Windows'))]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 14    8774 Jason Keys Suite 427\nEast Scottborough, ...  70 zH       AM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# ...                                                 ...    ...      ...
# 9988      0154 Green Forest\nNew Timothy, IL 33670-4620  11 MC       AM
# 9989         5674 Cruz Trace\nNew Shelby, KY 51047-5469  12 Kf       AM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
len(ecommerse[ecommerse['Browser Info'].str.contains('Windows')])
# Out:
# 4994

# %%
ecommerse[]

# %%
# 전체 사용자 중 윈도우, 리눅스, 맥 운영체제를 사용하는 사용자의 비율은?

# %%
# 윈도우
len(ecommerse[ecommerse['Browser Info'].str.contains('Windows')])
# Out:
# 4994

# %%
# 리눅스
len(ecommerse[ecommerse['Browser Info'].str.contains('Linux')])
# Out:
# 2322

# %%
# 맥
len(ecommerse[ecommerse['Browser Info'].str.contains('Mac')])
# Out:
# 2684

# %%
#총합 
len(ecommerse)
# Out:
# 10000

# %%
len(ecommerse[ecommerse['Browser Info'].str.contains('Windows')]) / len(ecommerse) *100
# Out:
# 49.94

# %%
len(ecommerse[ecommerse['Browser Info'].str.contains('Linux')]) / len(ecommerse) *100
# Out:
# 23.22

# %%
len(ecommerse[ecommerse['Browser Info'].str.contains('Mac')]) / len(ecommerse) * 100
# Out:
# 26.840000000000003

# %% [markdown]
# -----

# %%
ecommerse
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...
