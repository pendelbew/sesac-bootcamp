# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://dhlottery.co.kr/store.do?method=topStore&pageGubun=L645'

# %%
req = requests.get(url)

# %%
html = req.text

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title>동행복권</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/images/common/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/images/common/favicon.ico" rel="icon" type="image/x-icon"/>
# <script src="/js/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="/js/jquery-ui.js" type="text/javascript"></script>
# <script charset="utf-8" src="/js/common.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# fn_g_init_message("");
#
# var gameUserId = "";
#
# function goGame(){
# 	var userId = "";
#
# 	if(userId == '' || userId == null){
# 		alert("로그인 후 사용 해주시기 바랍니다.");
# 		location.href = "/user.do?method=login";
# 		return;
# 	}
#
# 	$.ajax({
# 		type:"get",                             // 메소드타입
# 		url:"https://el.dhlottery.co.kr/portal_login.jsp",    // url
# ...

# %%
soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr:nth-child(1) > td:nth-child(2)')
# Out:
# [<td>복권마을</td>]

# %%
name = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(2)')

# %%
name_list = []
for i in name:
    name_list.append(i.text)

# %%
name_list
# Out:
# ['복권마을',
#  '잠실매점',
#  '당첨로또',
#  '위너로또',
#  '라이프마트',
#  '알리바이',
#  '토큰박스',
#  '은미복권방',
#  '로또대박',
#  '대박명당',
#  '행운복권방',
#  '신불당로또',
#  '현대장미슈퍼',
#  '알리바이(나주점)',
#  '알리바이(나주점)',
#  '복권방']

# %%
gubun = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(3)')

# %%
gubun_list = []
for i in gubun:
    gubun_list.append((i.text).strip())

# %%
gubun_list
# Out:
# ['반자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동',
#  '자동']

# %%
addr = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(4)')

# %%
addr_list = []
for i in addr:
    addr_list.append(i.text)

# %%
addr_list
# Out:
# ['서울 구로구 구로동로 72 ',
#  '서울 송파구 올림픽로 269 잠실역 8번출구 앞 가판',
#  '부산 동구 범일로90번길 6-1 1층',
#  '인천 남동구 구월남로 212  동원프라자 101호',
#  '인천 중구 연안부두로53번길 36 5호',
#  '광주 광산구 수등로 253 1층 알리바이',
#  '경기 남양주시 진건오남로 112-1 동양할인마트 앞 로또판매점',
#  '경기 부천시 소사로794번길 6 ',
#  '경기 부천시 석천로177번길 11 제이클래스중동 1층 105호',
#  '경기 양주시 옥정동로5길 6 ',
#  '충북 청주시 상당구 단재로 119,(영운동) ',
#  '충남 천안시 서북구 불당21로 40 501동 지1층 B143호',
#  '전북 익산시 동서로61길 41 현대아파트1층108호',
#  '전남 나주시 나주로 142 알리바이',
#  '전남 나주시 나주로 142 알리바이',
#  '제주 서귀포시 상모로 326 ']

# %%
data = list(zip(name_list, gubun_list, addr_list))

# %%
data
# Out:
# [('복권마을', '반자동', '서울 구로구 구로동로 72 '),
#  ('잠실매점', '자동', '서울 송파구 올림픽로 269 잠실역 8번출구 앞 가판'),
#  ('당첨로또', '자동', '부산 동구 범일로90번길 6-1 1층'),
#  ('위너로또', '자동', '인천 남동구 구월남로 212  동원프라자 101호'),
#  ('라이프마트', '자동', '인천 중구 연안부두로53번길 36 5호'),
#  ('알리바이', '자동', '광주 광산구 수등로 253 1층 알리바이'),
#  ('토큰박스', '자동', '경기 남양주시 진건오남로 112-1 동양할인마트 앞 로또판매점'),
#  ('은미복권방', '자동', '경기 부천시 소사로794번길 6 '),
#  ('로또대박', '자동', '경기 부천시 석천로177번길 11 제이클래스중동 1층 105호'),
#  ('대박명당', '자동', '경기 양주시 옥정동로5길 6 '),
#  ('행운복권방', '자동', '충북 청주시 상당구 단재로 119,(영운동) '),
#  ('신불당로또', '자동', '충남 천안시 서북구 불당21로 40 501동 지1층 B143호'),
#  ('현대장미슈퍼', '자동', '전북 익산시 동서로61길 41 현대아파트1층108호'),
#  ('알리바이(나주점)', '자동', '전남 나주시 나주로 142 알리바이'),
#  ('알리바이(나주점)', '자동', '전남 나주시 나주로 142 알리바이'),
#  ('복권방', '자동', '제주 서귀포시 상모로 326 ')]

# %%
df = pd.DataFrame(data, columns = ['상호명','구분','소재지'])

# %%
df
# Out:
#           상호명   구분                                 소재지
# 0        복권마을  반자동                     서울 구로구 구로동로 72
# 1        잠실매점   자동       서울 송파구 올림픽로 269 잠실역 8번출구 앞 가판
# 2        당첨로또   자동                부산 동구 범일로90번길 6-1 1층
# 3        위너로또   자동         인천 남동구 구월남로 212  동원프라자 101호
# 4       라이프마트   자동               인천 중구 연안부두로53번길 36 5호
# 5        알리바이   자동              광주 광산구 수등로 253 1층 알리바이
# 6        토큰박스   자동  경기 남양주시 진건오남로 112-1 동양할인마트 앞 로또판매점
# 7       은미복권방   자동                  경기 부천시 소사로794번길 6
# 8        로또대박   자동  경기 부천시 석천로177번길 11 제이클래스중동 1층 105호
# 9        대박명당   자동                    경기 양주시 옥정동로5길 6
# 10      행운복권방   자동           충북 청주시 상당구 단재로 119,(영운동)
# 11      신불당로또   자동  충남 천안시 서북구 불당21로 40 501동 지1층 B143호
# 12     현대장미슈퍼   자동        전북 익산시 동서로61길 41 현대아파트1층108호
# 13  알리바이(나주점)   자동                 전남 나주시 나주로 142 알리바이
# 14  알리바이(나주점)   자동                 전남 나주시 나주로 142 알리바이
# 15        복권방   자동                    제주 서귀포시 상모로 326

# %%
name = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(2)')
gubun = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(3)')
addr = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(4)')

data = []
for i in range(len(name)):
    temp = []
    temp.append(name[i].text)
    temp.append(gubun[i].text.strip())
    temp.append(addr[i].text)
    data.append(temp)

# %%
data
# Out:
# [['복권마을', '반자동', '서울 구로구 구로동로 72 '],
#  ['잠실매점', '자동', '서울 송파구 올림픽로 269 잠실역 8번출구 앞 가판'],
#  ['당첨로또', '자동', '부산 동구 범일로90번길 6-1 1층'],
#  ['위너로또', '자동', '인천 남동구 구월남로 212  동원프라자 101호'],
#  ['라이프마트', '자동', '인천 중구 연안부두로53번길 36 5호'],
#  ['알리바이', '자동', '광주 광산구 수등로 253 1층 알리바이'],
#  ['토큰박스', '자동', '경기 남양주시 진건오남로 112-1 동양할인마트 앞 로또판매점'],
#  ['은미복권방', '자동', '경기 부천시 소사로794번길 6 '],
#  ['로또대박', '자동', '경기 부천시 석천로177번길 11 제이클래스중동 1층 105호'],
#  ['대박명당', '자동', '경기 양주시 옥정동로5길 6 '],
#  ['행운복권방', '자동', '충북 청주시 상당구 단재로 119,(영운동) '],
#  ['신불당로또', '자동', '충남 천안시 서북구 불당21로 40 501동 지1층 B143호'],
#  ['현대장미슈퍼', '자동', '전북 익산시 동서로61길 41 현대아파트1층108호'],
#  ['알리바이(나주점)', '자동', '전남 나주시 나주로 142 알리바이'],
#  ['알리바이(나주점)', '자동', '전남 나주시 나주로 142 알리바이'],
#  ['복권방', '자동', '제주 서귀포시 상모로 326 ']]

# %% [markdown]
# ---

# %%
https://dhlottery.co.kr/store.do?method=topStore&pageGubun=L645

# %%
url = 'https://dhlottery.co.kr/store.do?method=topStore&pageGubun=L645'

# %%
data = {'method':'topStore',
        'nowPage':'1',
        'rankNo':'',
        'gameNo':'5133',
        'drwNo':'1037',
        'schKey':'all',
        'schVal':''}

# %%
data
# Out:
# {'method': 'topStore',
#  'nowPage': '1',
#  'rankNo': '',
#  'gameNo': '5133',
#  'drwNo': '1037',
#  'schKey': 'all',
#  'schVal': ''}

# %%
req = request.post(url)
html = req.text
soup = BeautifulSoup(html, 'html.parser')

# %%
# 1000~1038

# %%
lotto = []
for i in range(1000, 1039):
    post_data = {'method':'topStore',
                 'nowPage':'1',
                 'rankNo':'',
                 'gameNo':'5133',
                 'drwNo':i,
                 'schKey':'all',
                 'schVal':''}
    
    req = requests.post(url)
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    
    name = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(2)')
    gubun = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(3)')
    addr = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(4)')

    for j in range(len(name)):
        temp = []
        temp.append(i)
        temp.append(j+1)
        temp.append(name[j].text)
        temp.append(gubun[j].text.strip())
        temp.append(addr[j].text)
        lotto.append(temp)

# %%
lotto
# Out:
# [[1000, 1, '복권마을', '반자동', '서울 구로구 구로동로 72 '],
#  [1000, 2, '잠실매점', '자동', '서울 송파구 올림픽로 269 잠실역 8번출구 앞 가판'],
#  [1000, 3, '당첨로또', '자동', '부산 동구 범일로90번길 6-1 1층'],
#  [1000, 4, '위너로또', '자동', '인천 남동구 구월남로 212  동원프라자 101호'],
#  [1000, 5, '라이프마트', '자동', '인천 중구 연안부두로53번길 36 5호'],
#  [1000, 6, '알리바이', '자동', '광주 광산구 수등로 253 1층 알리바이'],
#  [1000, 7, '토큰박스', '자동', '경기 남양주시 진건오남로 112-1 동양할인마트 앞 로또판매점'],
#  [1000, 8, '은미복권방', '자동', '경기 부천시 소사로794번길 6 '],
#  [1000, 9, '로또대박', '자동', '경기 부천시 석천로177번길 11 제이클래스중동 1층 105호'],
#  [1000, 10, '대박명당', '자동', '경기 양주시 옥정동로5길 6 '],
#  [1000, 11, '행운복권방', '자동', '충북 청주시 상당구 단재로 119,(영운동) '],
#  [1000, 12, '신불당로또', '자동', '충남 천안시 서북구 불당21로 40 501동 지1층 B143호'],
#  [1000, 13, '현대장미슈퍼', '자동', '전북 익산시 동서로61길 41 현대아파트1층108호'],
#  [1000, 14, '알리바이(나주점)', '자동', '전남 나주시 나주로 142 알리바이'],
#  [1000, 15, '알리바이(나주점)', '자동', '전남 나주시 나주로 142 알리바이'],
#  [1000, 16, '복권방', '자동', '제주 서귀포시 상모로 326 '],
#  [1001, 1, '복권마을', '반자동', '서울 구로구 구로동로 72 '],
# ...

# %%
df = pd.DataFrame(lotto, columns = ['회차', '순번', '상호명', '구분', '소재지'])

# %%
df
# Out:
#        회차  순번        상호명   구분                                 소재지
# 0    1000   1       복권마을  반자동                     서울 구로구 구로동로 72
# 1    1000   2       잠실매점   자동       서울 송파구 올림픽로 269 잠실역 8번출구 앞 가판
# 2    1000   3       당첨로또   자동                부산 동구 범일로90번길 6-1 1층
# 3    1000   4       위너로또   자동         인천 남동구 구월남로 212  동원프라자 101호
# 4    1000   5      라이프마트   자동               인천 중구 연안부두로53번길 36 5호
# ..    ...  ..        ...  ...                                 ...
# 619  1038  12      신불당로또   자동  충남 천안시 서북구 불당21로 40 501동 지1층 B143호
# 620  1038  13     현대장미슈퍼   자동        전북 익산시 동서로61길 41 현대아파트1층108호
# 621  1038  14  알리바이(나주점)   자동                 전남 나주시 나주로 142 알리바이
# 622  1038  15  알리바이(나주점)   자동                 전남 나주시 나주로 142 알리바이
# 623  1038  16        복권방   자동                    제주 서귀포시 상모로 326
#
# [624 rows x 5 columns]

# %%
df['소재지1'] = df['소재지'].str.split(' ', expand = True)[0]

# %%
df
# Out:
#        회차  순번        상호명   구분                                 소재지 소재지1
# 0    1000   1       복권마을  반자동                     서울 구로구 구로동로 72    서울
# 1    1000   2       잠실매점   자동       서울 송파구 올림픽로 269 잠실역 8번출구 앞 가판   서울
# 2    1000   3       당첨로또   자동                부산 동구 범일로90번길 6-1 1층   부산
# 3    1000   4       위너로또   자동         인천 남동구 구월남로 212  동원프라자 101호   인천
# 4    1000   5      라이프마트   자동               인천 중구 연안부두로53번길 36 5호   인천
# ..    ...  ..        ...  ...                                 ...  ...
# 619  1038  12      신불당로또   자동  충남 천안시 서북구 불당21로 40 501동 지1층 B143호   충남
# 620  1038  13     현대장미슈퍼   자동        전북 익산시 동서로61길 41 현대아파트1층108호   전북
# 621  1038  14  알리바이(나주점)   자동                 전남 나주시 나주로 142 알리바이   전남
# 622  1038  15  알리바이(나주점)   자동                 전남 나주시 나주로 142 알리바이   전남
# 623  1038  16        복권방   자동                    제주 서귀포시 상모로 326    제주
#
# [624 rows x 6 columns]
