# %%
import requests

# %%
url = 'https://www.koreabaseball.com/Record/Player/HitterBasic/BasicOld.aspx'

# %%
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}

# %%
req = requests.get(url, headers=headers)
html = req.text
soup = BeautifulSoup(html, 'html.parser')

# %%
req =

# %%
html = req.text

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup

# %%
soup.select('#cphContents_cphContents_cphContents_udpContent > div.record_result > table > tbody > tr:nth-child(1) > td:nth-child(2) > a')

# %%
soup.select('#cphContents_cphContents_cphContents_udpContent > div.record_result > table > tbody > tr:nth-child(2) > td:nth-child(2) > a')

# %%
name = soup.select('#cphContents_cphContents_cphContents_udpContent > div.record_result > table > tbody > tr > td:nth-child(2) > a')

# %%
'https://www.koreabaseball.com/' + name[0]['href']

# %%
for i in name:
    print(i.text)

# %%
soup.select('#cphContents_cphContents_cphContents_udpContent > div.record_result > table > tbody > tr:nth-child(1) > td:nth-child(3)')

# %%
team = soup.select('#cphContents_cphContents_cphContents_udpContent > div.record_result > table > tbody > tr > td:nth-child(3)')

# %%
for i in team:
    print(i.text)

# %%
name_l = []
for n in name:
    name_l.append(n.text)

# %%
team_l = []
for i in team:
    team_l.append(i.text)

# %%
name_l

# %%
team_l

# %%
data = list(zip(name_l, team_l))

# %%
import pandas as pd

# %%
data

# %%
df = pd.DataFrame(data, columns = ['선수명', '팀명'])

# %%
df

# %%
game = soup.select('#cphContents_cphContents_cphContents_udpContent > div.record_result > table > tbody > tr > td:nth-child(5)')

# %%
game_l = [] #경기
for g in game:
    game_l.append(g.text)

# %%
game_l

# %%
pa = soup.select('#cphContents_cphContents_cphContents_udpContent > div.record_result > table > tbody > tr > td:nth-child(6)')

# %%
pa_l = [] #타석
for p in pa:
    pa_l.append(p.text)

# %%
ab = soup.select('#cphContents_cphContents_cphContents_udpContent > div.record_result > table > tbody > tr > td:nth-child(7)')

# %%
ab_l = [] #타수
for a in ab:
    ab_l.append(a.text)

# %%
h = soup.select('#cphContents_cphContents_cphContents_udpContent > div.record_result > table > tbody > tr > td:nth-child(8)')

# %%
h_l = [] #안타
for i in h:
    h_l.append(i.text)

# %%
data = list(zip(name_l, team_l, game_l, pa_l, ab_l, h_l))

# %%
df = pd.DataFrame(data, columns = ['선수명', '팀명', '경기', '타석', '타수', '안타'])

# %%
df

# %%
soup.select('#cphContents_cphContents_cphContents_udpContent > div.record_result > table > tbody > tr > td:nth-child(4)')

# %%
avg = soup.select('#cphContents_cphContents_cphContents_udpContent > div.record_result > table > tbody > tr > td:nth-child(4)')

# %%
avg_l = []
for i in avg:
    avg_l.append(i.text)

# %%
data = list(zip(name_l, team_l, avg_l, game_l, pa_l, ab_l, h_l))

# %%
df = pd.DataFrame(data, columns =  ['선수명', '팀명', '타율', '경기', '타석', '타수', '안타'])

# %%
df

# %%
df['타수']= df['타수'].astype(int)

# %%
df['안타']= df['안타'].astype(int)

# %%
df['타율2']= df['안타'] / df['타수']

# %%
df['타율2'].

# %%
df['팀명'].value_counts()

# %%
df.to_csv('Hitter_2022.csv', index = False, encoding = 'euc-kr')

# %% [markdown]
# ---

# %%
import requests

# %%
url = 'https://dhlottery.co.kr/store.do?method=topStore&pageGubun=L645'

# %%
req = requests.get(url)

# %%
req
# Out:
# <Response [200]>

# %%
html = req.text

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title>동행복권</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/images/common/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/images/common/favicon.ico" rel="icon" type="image/x-icon"/>
# <script src="/js/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="/js/jquery-ui.js" type="text/javascript"></script>
# <script charset="utf-8" src="/js/common.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# fn_g_init_message("");
#
# var gameUserId = "";
#
# function goGame(){
# 	var userId = "";
#
# 	if(userId == '' || userId == null){
# 		alert("로그인 후 사용 해주시기 바랍니다.");
# 		location.href = "/user.do?method=login";
# 		return;
# 	}
#
# 	$.ajax({
# 		type:"get",                             // 메소드타입
# 		url:"https://el.dhlottery.co.kr/portal_login.jsp",    // url
# ...

# %%
name = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(2)')

# %%
name_l = []
for i in name:
    name_l.append(i.text)

# %%
name_l
# Out:
# ['복권마을',
#  '잠실매점',
#  '당첨로또',
#  '위너로또',
#  '라이프마트',
#  '알리바이',
#  '토큰박스',
#  '은미복권방',
#  '로또대박',
#  '대박명당',
#  '행운복권방',
#  '신불당로또',
#  '현대장미슈퍼',
#  '알리바이(나주점)',
#  '알리바이(나주점)',
#  '복권방']

# %%
auto = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(3)')

# %%
auto_l = []
for i in auto:
    auto_l.append((i.text).strip())
    
print(auto_l)
# Out:
# ['반자동', '자동', '자동', '자동', '자동', '자동', '자동', '자동', '자동', '자동', '자동', '자동', '자동', '자동', '자동', '자동']

# %%
auto_2 = []
for i in range(len(auto_l)):
    auto_2.append(auto_l[i].strip())

# %%
location = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(4)')

# %%
loc_l = []
for i in location:
    loc_l.append(i.text)

# %%
loc_l
# Out:
# ['서울 구로구 구로동로 72 ',
#  '서울 송파구 올림픽로 269 잠실역 8번출구 앞 가판',
#  '부산 동구 범일로90번길 6-1 1층',
#  '인천 남동구 구월남로 212  동원프라자 101호',
#  '인천 중구 연안부두로53번길 36 5호',
#  '광주 광산구 수등로 253 1층 알리바이',
#  '경기 남양주시 진건오남로 112-1 동양할인마트 앞 로또판매점',
#  '경기 부천시 소사로794번길 6 ',
#  '경기 부천시 석천로177번길 11 제이클래스중동 1층 105호',
#  '경기 양주시 옥정동로5길 6 ',
#  '충북 청주시 상당구 단재로 119,(영운동) ',
#  '충남 천안시 서북구 불당21로 40 501동 지1층 B143호',
#  '전북 익산시 동서로61길 41 현대아파트1층108호',
#  '전남 나주시 나주로 142 알리바이',
#  '전남 나주시 나주로 142 알리바이',
#  '제주 서귀포시 상모로 326 ']

# %%
data = list(zip(name_l, auto_2, loc_l))

# %%
import pandas as pd

# %%
df = pd.DataFrame(data, columns = ['상호명','구분','소재지'])

# %%
df
# Out:
#           상호명   구분                                 소재지
# 0        복권마을  반자동                     서울 구로구 구로동로 72
# 1        잠실매점   자동       서울 송파구 올림픽로 269 잠실역 8번출구 앞 가판
# 2        당첨로또   자동                부산 동구 범일로90번길 6-1 1층
# 3        위너로또   자동         인천 남동구 구월남로 212  동원프라자 101호
# 4       라이프마트   자동               인천 중구 연안부두로53번길 36 5호
# 5        알리바이   자동              광주 광산구 수등로 253 1층 알리바이
# 6        토큰박스   자동  경기 남양주시 진건오남로 112-1 동양할인마트 앞 로또판매점
# 7       은미복권방   자동                  경기 부천시 소사로794번길 6
# 8        로또대박   자동  경기 부천시 석천로177번길 11 제이클래스중동 1층 105호
# 9        대박명당   자동                    경기 양주시 옥정동로5길 6
# 10      행운복권방   자동           충북 청주시 상당구 단재로 119,(영운동)
# 11      신불당로또   자동  충남 천안시 서북구 불당21로 40 501동 지1층 B143호
# 12     현대장미슈퍼   자동        전북 익산시 동서로61길 41 현대아파트1층108호
# 13  알리바이(나주점)   자동                 전남 나주시 나주로 142 알리바이
# 14  알리바이(나주점)   자동                 전남 나주시 나주로 142 알리바이
# 15        복권방   자동                    제주 서귀포시 상모로 326

# %%
name = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(2)')
gubun = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(3)')
addr = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(4)')

lotto = []
for i in range(len(name)):
    temp = []
    temp.append(name[i].text)
    temp.append(gubun[i].text.strip())
    temp.append(addr[i].text)
    lotto.append(temp)

# %%
lotto
# Out:
# [['복권마을', '반자동', '서울 구로구 구로동로 72 '],
#  ['잠실매점', '자동', '서울 송파구 올림픽로 269 잠실역 8번출구 앞 가판'],
#  ['당첨로또', '자동', '부산 동구 범일로90번길 6-1 1층'],
#  ['위너로또', '자동', '인천 남동구 구월남로 212  동원프라자 101호'],
#  ['라이프마트', '자동', '인천 중구 연안부두로53번길 36 5호'],
#  ['알리바이', '자동', '광주 광산구 수등로 253 1층 알리바이'],
#  ['토큰박스', '자동', '경기 남양주시 진건오남로 112-1 동양할인마트 앞 로또판매점'],
#  ['은미복권방', '자동', '경기 부천시 소사로794번길 6 '],
#  ['로또대박', '자동', '경기 부천시 석천로177번길 11 제이클래스중동 1층 105호'],
#  ['대박명당', '자동', '경기 양주시 옥정동로5길 6 '],
#  ['행운복권방', '자동', '충북 청주시 상당구 단재로 119,(영운동) '],
#  ['신불당로또', '자동', '충남 천안시 서북구 불당21로 40 501동 지1층 B143호'],
#  ['현대장미슈퍼', '자동', '전북 익산시 동서로61길 41 현대아파트1층108호'],
#  ['알리바이(나주점)', '자동', '전남 나주시 나주로 142 알리바이'],
#  ['알리바이(나주점)', '자동', '전남 나주시 나주로 142 알리바이'],
#  ['복권방', '자동', '제주 서귀포시 상모로 326 ']]

# %%
data = {'method' : 'topStore',
        'nowPage' : '1',
        'rankNo' : '',
        'gameNo' : '5133',
        'drwNo' : '1037',
        'schKey' : 'all',
        'schVal' : ''}

# %%
data
# Out:
# {'method': 'topStore',
#  'nowPage': '1',
#  'rankNo': '',
#  'gameNo': '5133',
#  'drwNo': '1037',
#  'schKey': 'all',
#  'schVal': ''}

# %%
req = requests.post(url, data = data)
html = req.text
soup = BeautifulSoup(html, 'html.parser')

# %%
data
# Out:
# {'method': 'topStore',
#  'nowPage': '1',
#  'rankNo': '',
#  'gameNo': '5133',
#  'drwNo': '1037',
#  'schKey': 'all',
#  'schVal': ''}

# %%
name = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(2)')
gubun = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(3)')
addr = soup.select('#article > div:nth-child(2) > div > div:nth-child(4) > table > tbody > tr > td:nth-child(4)')

lotto = []
for i in range(len(name)):
    temp = []
    temp.append(name[i].text)
    temp.append(gubun[i].text.strip())
    temp.append(addr[i].text)
    lotto.append(temp)

# %%
lotto
# Out:
# [['지원물산', '자동', '서울 노원구 공릉로 108,(공릉동) '],
#  ['로또 명당', '자동', '대구 동구 화랑로75길 69 '],
#  ['초원복권 신창점', '자동', '광주 광산구 신창로 76 1층'],
#  ['대전우표사', '자동', '대전 동구 중앙로204번길 16-1 '],
#  ['대한유통', '자동', '울산 북구 박상진11로 1 1층112호'],
#  ['몽키버블티', '자동', '경기 군포시 고산로250번길 27 1층 일부호(당동)'],
#  ['꽃길', '수동', '경기 수원시 권선구 정조로 571 1층(세류동)'],
#  ['꽃길', '수동', '경기 수원시 권선구 정조로 571 1층(세류동)'],
#  ['행운복권방', '수동', '경기 안성시 서동대로 7184 1층 복권방'],
#  ['로또복권합정점', '수동', '경기 평택시 중앙로 176 127호 평택합정 SK뷰 주상복합'],
#  ['세븐일레븐화성봉담수기점', '자동', '경기 화성시 세자로 358 '],
#  ['포항오거리CU복권', '자동', '경북 포항시 북구 죽도로 33 CU포항오거리점내'],
#  ['삼정상회', '자동', '경남 김해시 활천로 23 가동 109호 복권판매점'],
#  ['목화휴게소', '자동', '경남 사천시 사천대로 912 '],
#  ['신세계', '자동', '제주 제주시 고마로14길 7 ']]

# %% [markdown]
# ---------------
