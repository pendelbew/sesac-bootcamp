# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
heart = pd.read_csv('heart.csv')

# %%
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heart[heart.duplicated()]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %%
heart[heart['chol'] == 175]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 27    51    1   2       110   175    0        1      123      0      0.6
# 163   38    1   2       138   175    0        1      173      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 27       2   0     2       1
# 163      2   4     2       1
# 164      2   4     2       1

# %%
heart = heart.drop_duplicates()

# %%
heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# ---

# %%
from sklearn.model_selection import train_test_split

# %%
x = heart.drop(['target'], axis = 1)

# %%
x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
y = heart['target']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pol = PolynomialFeatures(degree = 2)

# %%
x_pol = pol.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_pol, y, test_size = 0.2, random_state = 2)

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x_train, y_train)
# Out:
# 0.8630705394190872

# %%
model.score(x_test, y_test)
# Out:
# 0.8852459016393442

# %%
model.coef_
# Out:
# array([[ 1.98074574e-07,  9.15752091e-06, -8.96497078e-06,
#          9.53441197e-06,  1.80735840e-05, -2.15050608e-06,
#         -2.48522573e-07,  3.86045546e-06,  2.85056231e-05,
#         -5.75812460e-06, -7.21832708e-06,  4.90066086e-06,
#         -7.29690977e-06, -1.01867167e-05,  8.33675670e-04,
#         -5.14208041e-04,  5.34184858e-04,  7.93378384e-04,
#         -1.97668980e-04, -2.97436937e-05,  2.80239137e-04,
#         -7.94009294e-04, -3.18192333e-04, -3.74415192e-04,
#          2.65294165e-04, -4.57616756e-04, -5.26602875e-04,
#         -8.96497078e-06, -2.67541689e-06, -1.14287561e-03,
#         -2.28002873e-03, -1.57969602e-07, -1.43529346e-06,
#         -1.28113623e-03, -5.33608964e-06, -1.25471024e-05,
#         -1.02336498e-05, -8.76765825e-06, -2.53998413e-05,
#          1.42589070e-05,  1.28917702e-03,  1.97485828e-03,
#          2.55480678e-06,  7.14372416e-06,  1.45145482e-03,
#          1.99573642e-06,  7.64295541e-06,  1.59627175e-05,
# ...

# %%
model.intercept_
# Out:
# array([1.98074281e-07])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(predict, y_test)
# Out:
# 0.14754098360655737

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train1 = scaler.fit_transform(x_train)

# %%
x_test1 = scaler.transform(x_test)

# %%
model.fit(x_train1, y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_train1, y_train)
# Out:
# 0.8506224066390041

# %%
model.score(x_test1, y_test)
# Out:
# 0.8688524590163934

# %%
real = [35, 1, 2, 135, 240, 0, 0, 160, 1, 2.1, 1, 0, 1]

# %%
import numpy as np

# %%
real = np.asarray(real).reshape(1,-1)

# %%
real = pol.transform(real)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
from sklearn.linear_model import LogisticRegressionCV

# %%
model2 = LogisticRegressionCV()

# %%
model2.fit(x_train, y_train)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
model2.score(x_train, y_train)
# Out:
# 0.8464730290456431

# %%
model2.score(x_test, y_test)
# Out:
# 0.8852459016393442

# %%
import pickle

# %%
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
with open('model2_1.pkl', 'wb') as f:
    pickle.dump(model2, f)

# %%
with open('model1.pkl', 'wb') as f:
    pickle.dump(model, f)
