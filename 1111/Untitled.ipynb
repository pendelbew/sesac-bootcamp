# %%
import pandas as pd

# %%
loan = pd.read_csv('loan.csv')

# %%
loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan[loan['Gender'].isnull()]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 23   LP001050    NaN     Yes          2  Not Graduate            No
# 126  LP001448    NaN     Yes         3+      Graduate            No
# 171  LP001585    NaN     Yes         3+      Graduate            No
# 188  LP001644    NaN     Yes          0      Graduate           Yes
# 314  LP002024    NaN     Yes          0      Graduate            No
# 334  LP002103    NaN     Yes          1      Graduate           Yes
# 460  LP002478    NaN     Yes          0      Graduate           Yes
# 467  LP002501    NaN     Yes          0      Graduate            No
# 477  LP002530    NaN     Yes          2      Graduate            No
# 507  LP002625    NaN      No          0      Graduate            No
# 576  LP002872    NaN     Yes          0      Graduate            No
# 588  LP002925    NaN      No          0      Graduate            No
# 592  LP002933    NaN      No         3+      Graduate           Yes
#
# ...

# %%
loan.groupby('Gender')['Loan_Status'].count()
# Out:
# Gender
# Female    112
# Male      489
# Name: Loan_Status, dtype: int64

# %%
loan[loan['Married'].isnull()]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 104  LP001357    Male     NaN        NaN  Graduate            No
# 228  LP001760    Male     NaN        NaN  Graduate            No
# 435  LP002393  Female     NaN        NaN  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 104             3816              754.0       160.0             360.0
# 228             4758                0.0       158.0             480.0
# 435            10047                0.0         NaN             240.0
#
#      Credit_History Property_Area Loan_Status
# 104             1.0         Urban           Y
# 228             1.0     Semiurban           Y
# 435             1.0     Semiurban           Y

# %%
loan.groupby('Married')['Loan_Status'].count()
# Out:
# Married
# No     213
# Yes    398
# Name: Loan_Status, dtype: int64

# %%
loan[loan['Dependents'].isnull()]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 102  LP001350    Male     Yes        NaN      Graduate            No
# 104  LP001357    Male     NaN        NaN      Graduate            No
# 120  LP001426    Male     Yes        NaN      Graduate            No
# 226  LP001754    Male     Yes        NaN  Not Graduate           Yes
# 228  LP001760    Male     NaN        NaN      Graduate            No
# 293  LP001945  Female      No        NaN      Graduate            No
# 301  LP001972    Male     Yes        NaN  Not Graduate            No
# 332  LP002100    Male      No        NaN      Graduate            No
# 335  LP002106    Male     Yes        NaN      Graduate           Yes
# 346  LP002130    Male     Yes        NaN  Not Graduate            No
# 355  LP002144  Female      No        NaN      Graduate            No
# 435  LP002393  Female     NaN        NaN      Graduate            No
# 517  LP002682    Male     Yes        NaN  Not Graduate            No
# ...

# %%
loan[(loan['Dependents'].isnull()) & (loan['Married'] == 'Yes')]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 102  LP001350   Male     Yes        NaN      Graduate            No
# 120  LP001426   Male     Yes        NaN      Graduate            No
# 226  LP001754   Male     Yes        NaN  Not Graduate           Yes
# 301  LP001972   Male     Yes        NaN  Not Graduate            No
# 335  LP002106   Male     Yes        NaN      Graduate           Yes
# 346  LP002130   Male     Yes        NaN  Not Graduate            No
# 517  LP002682   Male     Yes        NaN  Not Graduate            No
# 571  LP002847   Male     Yes        NaN      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 102            13650                0.0         NaN             360.0
# 120             5667             2667.0       180.0             360.0
# 226             4735                0.0       138.0             360.0
# 301             2875             1750.0       105.0             360.0
# ...

# %%
loan[(loan['Dependents'].isnull()) & (loan['Married'] == 'No')]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 293  LP001945  Female      No        NaN  Graduate            No
# 332  LP002100    Male      No        NaN  Graduate            No
# 355  LP002144  Female      No        NaN  Graduate            No
# 597  LP002943    Male      No        NaN  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 293             5417                0.0       143.0             480.0
# 332             2833                0.0        71.0             360.0
# 355             3813                0.0       116.0             180.0
# 597             2987                0.0        88.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 293             0.0         Urban           N
# 332             1.0         Urban           Y
# 355             1.0         Urban           Y
# 597             0.0     Semiurban           N

# %%
loan['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
loan['Dependents'].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
len(loan[(loan['Dependents'] == '1') & (loan['Married'] == 'No')])
# Out:
# 23

# %%
len(loan[(loan['Dependents'] == '0') & (loan['Married'] == 'No')])
# Out:
# 171

# %%
import numpy as np

# %%
loan[loan['Married'].isnull()]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 104  LP001357    Male     NaN        NaN  Graduate            No
# 228  LP001760    Male     NaN        NaN  Graduate            No
# 435  LP002393  Female     NaN        NaN  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 104             3816              754.0       160.0             360.0
# 228             4758                0.0       158.0             480.0
# 435            10047                0.0         NaN             240.0
#
#      Credit_History Property_Area Loan_Status
# 104             1.0         Urban           Y
# 228             1.0     Semiurban           Y
# 435             1.0     Semiurban           Y

# %%
for i in loan:
    if loan['CoapplicantIncome'] == 0.0:

# %%
loan.iloc[104]
# Out:
# Loan_ID              LP001357
# Gender                   Male
# Married                    No
# Dependents                NaN
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          3816
# CoapplicantIncome       754.0
# LoanAmount              160.0
# Loan_Amount_Term        360.0
# Credit_History            1.0
# Property_Area           Urban
# Loan_Status                 Y
# Name: 104, dtype: object

# %%
loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan.groupby('Married')['Dependents'].value_counts()
# Out:
# Married  Dependents
# No       0             171
#          1              23
#          2               8
#          3+              7
# Yes      0             174
#          2              93
#          1              79
#          3+             44
# Name: Dependents, dtype: int64

# %%
loan[loan['Self_Employed'].isnull()]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 19   LP001041    Male     Yes          0      Graduate           NaN
# 24   LP001052    Male     Yes          1      Graduate           NaN
# 29   LP001087  Female      No          2      Graduate           NaN
# 30   LP001091    Male     Yes          1      Graduate           NaN
# 95   LP001326    Male      No          0      Graduate           NaN
# 107  LP001370    Male      No          0  Not Graduate           NaN
# 111  LP001387  Female     Yes          0      Graduate           NaN
# 114  LP001398    Male      No          0      Graduate           NaN
# 158  LP001546    Male      No          0      Graduate           NaN
# 170  LP001581    Male     Yes          0  Not Graduate           NaN
# 218  LP001732    Male     Yes          2      Graduate           NaN
# 231  LP001768    Male     Yes          0      Graduate           NaN
# ...

# %%
loan['Self_Employed'].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
loan.groupby('Self_Employed')['ApplicantIncome'].median()
# Out:
# Self_Employed
# No     3705.5
# Yes    5809.0
# Name: ApplicantIncome, dtype: float64

# %%
loan.groupby('Self_Employed')['CoapplicantIncome'].median()
# Out:
# Self_Employed
# No     1293.5
# Yes       0.0
# Name: CoapplicantIncome, dtype: float64

# %%
loan.groupby('Self_Employed')['CoapplicantIncome'].value_counts()
# Out:
# Self_Employed  CoapplicantIncome
# No             0.0                  213
#                1666.0                 5
#                2500.0                 4
#                1625.0                 3
#                1750.0                 3
#                                    ...
# Yes            4983.0                 1
#                5296.0                 1
#                7166.0                 1
#                7873.0                 1
#                20000.0                1
# Name: CoapplicantIncome, Length: 287, dtype: int64

# %%
loan.groupby('Self_Employed')['LoanAmount'].median()
# Out:
# Self_Employed
# No     125.0
# Yes    150.0
# Name: LoanAmount, dtype: float64

# %%
loan.groupby('Self_Employed')['Loan_Amount_Term'].median()
# Out:
# Self_Employed
# No     360.0
# Yes    360.0
# Name: Loan_Amount_Term, dtype: float64

# %%
loan['Loan_Amount_Term'].unique() # 12개월 단위??
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
loan.groupby('Self_Employed')['Property_Area'].value_counts()
# Out:
# Self_Employed  Property_Area
# No             Semiurban        191
#                Urban            166
#                Rural            143
# Yes            Semiurban         32
#                Rural             26
#                Urban             24
# Name: Property_Area, dtype: int64

# %%
loan['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
loan[loan['Credit_History'].isnull()]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 16   LP001034    Male      No          1  Not Graduate            No
# 24   LP001052    Male     Yes          1      Graduate           NaN
# 30   LP001091    Male     Yes          1      Graduate           NaN
# 42   LP001123    Male     Yes          0      Graduate            No
# 79   LP001264    Male     Yes         3+  Not Graduate           Yes
# 83   LP001273    Male     Yes          0      Graduate            No
# 86   LP001280    Male     Yes          2  Not Graduate            No
# 95   LP001326    Male      No          0      Graduate           NaN
# 117  LP001405    Male     Yes          1      Graduate            No
# 125  LP001443  Female      No          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 130  LP001469    Male      No          0      Graduate           Yes
# 156  LP001541    Male     Yes          1      Graduate            No
# ...
