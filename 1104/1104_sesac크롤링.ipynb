# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://sesac.seoul.kr/usr/member/dash/detail.do'
headers = {'Cookie' : '_ga=GA1.1.1962770585.1667803921; page_logintype=1; InitechEamUID_V42=uTq8nOAlCY5qK5WM6utwdg%3D%3D; InitechEamUIP_V42=ObI%2BsLG6D4mrVazs8DBKHA%3D%3D; InitechEamUTOA_V42=1; InitechEamUPID_V42=j3mVpo3U0M3pvdUTRFS4uw%3D%3D; _BS_GUUID=dsgvnloeEjWxhUzMFuqHsEyBRQpKi4FvxW0Uho9V; _TRK_UID=9430bb569f0c48d10f0008832ab9eabc:1:0:1667803928162; _TRK_SID=4c43bce227930c886ecbd424302fb074; _TRK_CR=http%3A%2F%2Fnsso.sba.seoul.kr%3A8090%2F; JSESSIONID=33EFE7414A5CC8CB8A2D1EBC3674D36B; InitechEamULAT_V42=1667804037; InitechEamUHMAC_V42=3TrZDJkPgVzA0YOIysjwClXWO0NWxJP8wCb1R6Luoy8%3D; _ga_ZLMCDSG8JM=GS1.1.1667803920.1.1.1667804036.0.0.0; _TRK_EX=2'}

# %%
req = requests.get(url, headers = headers)

# %%
soup = BeautifulSoup(req.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="ko" lang="ko">
# <link href="/static/common/font/material-icons.css" rel="stylesheet" type="text/css"/>
# <link href="/static/common/font/notosanskr.css" rel="stylesheet" type="text/css"/>
# <link href="/static/common/font/nanumsquare.css" rel="stylesheet" type="text/css"/>
# <link href="/static/common/font/nanumsquareround.css" rel="stylesheet" type="text/css"/>
# <link href="/static/common/css/www/common.css" rel="stylesheet" type="text/css"/>
# <link href="/static/common/css/www/daterangepicker.min.css" rel="stylesheet" type="text/css"/>
# <link href="/static/common/images/www/common/ic.ico" rel="shortcut icon"/>
# <!-- kendo -->
# <link href="/static/js/3rdparty/kendoui/styles/kendo.common.min.css" rel="stylesheet"/>
# <link href="/static/js/3rdparty/kendoui/styles/kendo.bootstrap.min.css" rel="stylesheet"/>
# <!-- //kendo -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# ...

# %%
soup.select('#s2_02 > div > table > tbody > tr > td.al > a')[0].text
# Out:
# '(금천2기)기업데이터를 활용한 AI 취업 부트캠프'

# %%
url2 = 'https://sesac.seoul.kr/usr/member/dash/detail.do'

# %%
req2 = requests.get(url2)
soup2 = BeautifulSoup(req2.text, 'html.parser')

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 7]><html lang="ko" class="old ie7"><![endif]-->
# <!--[if IE 8]><html lang="ko" class="old ie8"><![endif]-->
# <!--[if IE 9]><html lang="ko" class="modern ie9"><![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html class="modern" lang="ko">
# <!--<![endif]--><head>
# <title>청년취업사관학교</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="no-cache" http-equiv="Cache-control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no" name="viewport"/>
# <meta content="telephone=no, address=no, email=no" name="format-detection"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-ZLMCDSG8JM"></script>
# <script>
# ...

# %%
soup2.select('#s2_02 > div > table > tbody > tr > td.al > a')
# Out:
# []
