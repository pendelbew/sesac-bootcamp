# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

import tqdm as tqdm

# %%
url = 'https://www.imdb.com/chart/boxoffice/?ref_=nv_ch_cht'

# %%
req = requests.get(url)

# %%
soup = BeautifulSoup(req.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <style>
#                 body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#             </style>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>IMDb Top Box Office - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
# ...

# %%
soup.select('#boxoffice > table > tbody > tr:nth-child(1) > td > td.titleColumn > a')[0].text.strip()
# Out:
# 'Black Adam'

# %%
title = soup.select('#boxoffice > table > tbody > tr > td > td > a')

# %%
title
# Out:
# [<a href="/title/tt6443346" title="Jaume Collet-Serra (dir.), Dwayne Johnson, Aldis Hodge">Black Adam</a>,
#  <a href="/title/tt14109724" title="Ol Parker (dir.), George Clooney, Sean Lynch">Ticket to Paradise</a>,
#  <a href="/title/tt9271672" title="Daniel Stamm (dir.), Jacqueline Byers, Virginia Madsen">Prey for the Devil</a>,
#  <a href="/title/tt15474916" title="Parker Finn (dir.), Sosie Bacon, Jessie T. Usher">Smile</a>,
#  <a href="/title/tt10665342" title="David Gordon Green (dir.), Jamie Lee Curtis, Andi Matichak">Halloween Ends</a>,
#  <a href="/title/tt4960748" title="Chinonye Chukwu (dir.), Danielle Deadwyler, Jalyn Hall">Till</a>,
#  <a href="/title/tt14668630" title="Josh Gordon (dir.), Javier Bardem, Constance Wu">Lyle, Lyle, Crocodile</a>,
#  <a href="/title/tt10403420" title="Damien Leone (dir.), Lauren LaVera, David Howard Thornton">Terrifier 2</a>,
#  <a href="/title/tt8093700" title="Gina Prince-Bythewood (dir.), Viola Davis, Thuso Mbedu">The Woman King</a>,
# ...

# %%
title_list = []
for i in title:
    print(i.text)
    title_list.append(i.text)
# Out:
# Black Adam
# Ticket to Paradise
# Prey for the Devil
# Smile
# Halloween Ends
# Till
# Lyle, Lyle, Crocodile
# Terrifier 2
# The Woman King
# Tár

# %%
title_list
# Out:
# ['Black Adam',
#  'Ticket to Paradise',
#  'Prey for the Devil',
#  'Smile',
#  'Halloween Ends',
#  'Till',
#  'Lyle, Lyle, Crocodile',
#  'Terrifier 2',
#  'The Woman King',
#  'Tár']

# %%
title2 = soup.findAll('td', {'class': 'titleColumn'})

# %%
for i in title2:
    print(i.text)
# Out:
# Black Adam
#
#
# Ticket to Paradise
#
#
# Prey for the Devil
#
#
# Smile
#
#
# Halloween Ends
#
#
# Till
#
#
# Lyle, Lyle, Crocodile
#
#
# Terrifier 2
#
#
# The Woman King
#
#
# Tár

# %%
url_2 = 'https://www.imdb.com/title/tt6443346/reviews?ref_=tt_urv'

# %%
soup.select('#boxoffice > table > tbody > tr > td > td.titleColumn > a')
# Out:
# [<a href="/title/tt6443346" title="Jaume Collet-Serra (dir.), Dwayne Johnson, Aldis Hodge">Black Adam</a>,
#  <a href="/title/tt14109724" title="Ol Parker (dir.), George Clooney, Sean Lynch">Ticket to Paradise</a>,
#  <a href="/title/tt9271672" title="Daniel Stamm (dir.), Jacqueline Byers, Virginia Madsen">Prey for the Devil</a>,
#  <a href="/title/tt15474916" title="Parker Finn (dir.), Sosie Bacon, Jessie T. Usher">Smile</a>,
#  <a href="/title/tt10665342" title="David Gordon Green (dir.), Jamie Lee Curtis, Andi Matichak">Halloween Ends</a>,
#  <a href="/title/tt4960748" title="Chinonye Chukwu (dir.), Danielle Deadwyler, Jalyn Hall">Till</a>,
#  <a href="/title/tt14668630" title="Josh Gordon (dir.), Javier Bardem, Constance Wu">Lyle, Lyle, Crocodile</a>,
#  <a href="/title/tt10403420" title="Damien Leone (dir.), Lauren LaVera, David Howard Thornton">Terrifier 2</a>,
#  <a href="/title/tt8093700" title="Gina Prince-Bythewood (dir.), Viola Davis, Thuso Mbedu">The Woman King</a>,
# ...

# %%
review = []
for i in range(len(title_list)):
    print(soup.select('#boxoffice > table > tbody > tr > td > td.titleColumn > a')[i]['href'])
    review.append(soup.select('#boxoffice > table > tbody > tr > td > td.titleColumn > a')[i]['href'])
# Out:
# /title/tt6443346
# /title/tt14109724
# /title/tt9271672
# /title/tt15474916
# /title/tt10665342
# /title/tt4960748
# /title/tt14668630
# /title/tt10403420
# /title/tt8093700
# /title/tt14444726

# %%
review
# Out:
# ['/title/tt6443346',
#  '/title/tt14109724',
#  '/title/tt9271672',
#  '/title/tt15474916',
#  '/title/tt10665342',
#  '/title/tt4960748',
#  '/title/tt14668630',
#  '/title/tt10403420',
#  '/title/tt8093700',
#  '/title/tt14444726']

# %%
review_link = []
review_title_list = []
for i in review:
    temp = 'https://www.imdb.com/' + i + '/reviews?ref_=tt_urv'
    review_link.append(temp)
    
    for i in review_link:
        req2 = requests.get(i)
        soup2 = BeautifulSoup(req2.text, 'html.parser')
        
        review_title = soup2.select('#main > section > div.lister > div.lister-list > div > div.review-container > div.lister-item-content > a')
        
        for reviewtitle in review_title:
            review_title_list.append(reviewtitle.text.strip())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [223], in <cell line: 3>()
#       5 review_link.append(temp)
#       7 for i in review_link:
# ----> 8     req2 = requests.get(i)
#       9     soup2 = BeautifulSoup(req2.text, 'html.parser')
#      11     review_title = soup2.select('#main > section > div.lister > div.lister-list > div > div.review-container > div.lister-item-content > a')
#
# File ~\anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
# ...

# %%
review_list
# Out:
# ['https://www.imdb.com//title/tt6443346/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt14109724/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt9271672/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt15474916/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt10665342/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt4960748/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt14668630/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt10403420/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt8093700/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt14444726/reviews?ref_=tt_urv']

# %%
req2 = requests.get(url_2)

# %%
soup2 = BeautifulSoup(req2.text, 'html.parser')

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>블랙 아담 (2022) - 블랙 아담 (2022) - User Reviews - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/title/tt6443346/reviews" rel="canonical"/>
# ...

# %%
review_title = soup2.select('#main > section > div.lister > div.lister-list > div > div.review-container > div.lister-item-content > a')

# %%
review_title_list = []
for reviewtitle in review_title:
    review_title_list.append(reviewtitle.text.strip())

# %%
review_title_list
# Out:
# ["Black Adam Is Not Perfect But It's Still Great, It's Still Fun, It's Still Fascinating, It's Still Exciting, And I Enjoy The Hell Out Of It",
#  'If Michael Bay & Zack Snyder had a baby',
#  'Are they really any bad or good Superhero ?',
#  'Fast paced action and kinda fun',
#  'It was surprisingly fun!',
#  'Never seen a movie so bad that I still enjoyed...',
#  'Flawed but pretty good and mostly fun',
#  'Delivers explosive action scenes with great special effects that should satisfy fans of the superhero genre',
#  'Visually stunning DC film has lots of action violence, some laughs and an outstanding cast',
#  "It's okay",
#  'A good and fun superhero movie',
#  'Potential halted by skateboards and weak supports',
#  'Just fine!',
#  'I was shocked by how much I disliked Black Adam.',
#  'Derivative but refreshingly unpretentious',
#  "It's maybe a little more than mid... That's it",
#  'Ambitious, loud, and a screenwriting train-wreck.',
#  'A Rock movie',
# ...

# %%
review_link = []
review_title_list = []
for i in review:
    temp = 'https://www.imdb.com/' + i + '/reviews?ref_=tt_urv'
    review_link.append(temp)

# %%
review_link
# Out:
# ['https://www.imdb.com//title/tt6443346/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt14109724/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt9271672/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt15474916/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt10665342/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt4960748/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt14668630/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt10403420/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt8093700/reviews?ref_=tt_urv',
#  'https://www.imdb.com//title/tt14444726/reviews?ref_=tt_urv']

# %%
for i in review_link:
    req2 = requests.get(i)
    soup2 = BeautifulSoup(req2.text, 'html.parser')
    review_title = soup2.select('#main > section > div.lister > div.lister-list > div > div.review-container > div.lister-item-content > a')
    
    temp = []
    for reviewtitle in review_title:
        temp.append(reviewtitle.text.strip())
    review_title_list.append(temp)

# %%
review_title_list
# Out:
# ["Black Adam Is Not Perfect But It's Still Great, It's Still Fun, It's Still Fascinating, It's Still Exciting, And I Enjoy The Hell Out Of It",
#  'If Michael Bay & Zack Snyder had a baby',
#  'Are they really any bad or good Superhero ?',
#  'Fast paced action and kinda fun',
#  'It was surprisingly fun!',
#  'Never seen a movie so bad that I still enjoyed...',
#  'Flawed but pretty good and mostly fun',
#  'Delivers explosive action scenes with great special effects that should satisfy fans of the superhero genre',
#  'Visually stunning DC film has lots of action violence, some laughs and an outstanding cast',
#  "It's okay",
#  'A good and fun superhero movie',
#  'Potential halted by skateboards and weak supports',
#  'Just fine!',
#  'I was shocked by how much I disliked Black Adam.',
#  'Derivative but refreshingly unpretentious',
#  "It's maybe a little more than mid... That's it",
#  'Ambitious, loud, and a screenwriting train-wreck.',
#  'A Rock movie',
# ...

# %%
review_content_list = []
for i in review_link:
    req2 = requests.get(i)
    soup2 = BeautifulSoup(req2.text, 'html.parser')
    review_content = soup2.select('#main > section > div.lister > div.lister-list > div > div > div.lister-item-content > div.content > div.text.show-more__control')
    
    temp = []
    for content in review_content:
        temp.append(content.text.strip())
    review_content_list.append(temp)

# %%
review_content_list
# Out:
# [["Black Adam is not without its flaws, but i still enjoy the hell out of it, the problem that i have with Black Adam is that i never really buy all the Kahndaq people 100%, in the end i only still buy half of it, but i still fine with it, it's not like their characters are terrible, it just most of the time they are doing just a poor performance except the actress who played the mom and probably Ishmael for the most part, at least i still got some of the laughs from one of them, some of the slower scene was sometimes misplaced including some of the flashback, and some nit picky here and there, the rest of Black Adam is an exciting comic book film that fills with a very impressive battle that also fills with dazzling visual and cool style, Black Adam himself played incredibly well by Dwayne Johnson, he was just unstoppable in the most badass way, Justice Society has just become one of my favorite superhero team specifically in movies, they are fun and they are great, Hawkman, Doctor 
# ...

# %%
review_rates

# %%
soup.select('#main > section > div.lister > div.lister-list > div.review-container > div.lister-item-content > div.ipl-ratings-bar > span')
# Out:
# []

# %%
<div class="lister-list">
<div class="lister-item mode-detail imdb-user-review collapsable" data-review-id="rw8623676" data-vote-url="/title/tt6443346/review/rw8623676/vote/interesting">
<div class="review-container">
<div class="lister-item-content">
<div class="ipl-ratings-bar">

<span>8</span><span class="point-scale">/10</span>
