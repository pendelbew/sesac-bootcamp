# %%
import requests

# %%
url = 'https://product.kyobobook.co.kr/api/gw/pub/pdt/best-seller/online?page=1&per=20&period=001&dsplDvsnCode=000&dsplTrgtDvsnCode=001'

# %%
req = requests.get(url).json()

# %%
req
# Out:
# {'data': {'bestSeller': [{'prstRnkn': 1,
#     'imgPath': '',
#     'recdCode': '',
#     'saleCmdtid': 'S000061863239',
#     'saleCmdtGrpDvsnCode': 'SGK',
#     'cmdtName': '트렌드 코리아 2023',
#     'chrcName': '김난도 외',
#     'pbcmName': '미래의창',
#     'ppbkRlseDate': '',
#     'rlseDate': '20221005',
#     'inbukCntt': '세계화의 종말, 갈등과 분열, 그리고 전쟁. 수십 년간 이어져 온 평화와 공존의 시대는 막을 내리고 엄청난 위기감 속에서 사람들은 다가올 미래를 두려워한다. 자산시장 및 증시의 버블붕괴는 마치 2008년 글로벌 경제위기의 데자뷔를 보는 듯하다. 제2의 외환위기 경고도 들려온다. 매우 부정적인 전망이 압도하는 2023년을 목전에 두고 있는 지금, 소비 트렌드 전망에서 가장 중요한 것은 무엇이 반복되고 무엇이 달라질 것인가를 구별하는 작업일 것이다. 즉, ‘불황기의 소비 패턴’을 과거와 비교해보는 것이고, 또 하나는 ‘소비의 전형성’이 사라지는 시대의 흐름을 분석하는 것이다. 이른바 ‘평균 실종’이 가장 첫 번째 키워드인 이유다. 변화의 속도가 더욱 빨라지는 2023 대한민국. 소비자들은 어떤 선택을 할 것인가?',
#     'price': 19000.0,
#     'sapr': 17100.0,
#     'dscnRate': 10,
#     'upntAcmlAmnt': 950,
#     'buyRevwNumc': 963,
#     'buyRevwRvgr': 9.3,
#     'revwEmtnKywrName': '도움돼요',
#     'frmrRnkn': 2,
#     'preview': True,
#     'likeWhether': False,
# ...

# %%
req['data']['bestSeller'][0]
# Out:
# {'prstRnkn': 1,
#  'imgPath': '',
#  'recdCode': '',
#  'saleCmdtid': 'S000061863239',
#  'saleCmdtGrpDvsnCode': 'SGK',
#  'cmdtName': '트렌드 코리아 2023',
#  'chrcName': '김난도 외',
#  'pbcmName': '미래의창',
#  'ppbkRlseDate': '',
#  'rlseDate': '20221005',
#  'inbukCntt': '세계화의 종말, 갈등과 분열, 그리고 전쟁. 수십 년간 이어져 온 평화와 공존의 시대는 막을 내리고 엄청난 위기감 속에서 사람들은 다가올 미래를 두려워한다. 자산시장 및 증시의 버블붕괴는 마치 2008년 글로벌 경제위기의 데자뷔를 보는 듯하다. 제2의 외환위기 경고도 들려온다. 매우 부정적인 전망이 압도하는 2023년을 목전에 두고 있는 지금, 소비 트렌드 전망에서 가장 중요한 것은 무엇이 반복되고 무엇이 달라질 것인가를 구별하는 작업일 것이다. 즉, ‘불황기의 소비 패턴’을 과거와 비교해보는 것이고, 또 하나는 ‘소비의 전형성’이 사라지는 시대의 흐름을 분석하는 것이다. 이른바 ‘평균 실종’이 가장 첫 번째 키워드인 이유다. 변화의 속도가 더욱 빨라지는 2023 대한민국. 소비자들은 어떤 선택을 할 것인가?',
#  'price': 19000.0,
#  'sapr': 17100.0,
#  'dscnRate': 10,
#  'upntAcmlAmnt': 950,
#  'buyRevwNumc': 963,
#  'buyRevwRvgr': 9.3,
#  'revwEmtnKywrName': '도움돼요',
#  'frmrRnkn': 2,
#  'preview': True,
#  'likeWhether': False,
#  'saleCmdtDvsnCode': 'KOR',
#  'saleCmdtPrceCurnUntCode': '011',
#  'saleCmdtClstCode': '130911',
# ...

# %%
for bs in req['data']['bestSeller'] :
    print(bs['cmdtName'])
# Out:
# 트렌드 코리아 2023
# 아버지의 해방일지
# 나의 히어로 아카데미아 36 + 2023 캘린더(한정판)
# 하얼빈
# 잘될 수밖에 없는 너에게
# 에그박사 8
# 불편한 편의점 2(단풍 에디션)
# 불편한 편의점(40만부 기념 벚꽃 에디션)
# 기억의 뇌과학
# 세상에서 가장 쉬운 본질육아
# 역행자
# 마흔에 읽는 니체
# 원피스 103: 해방의 전사
# 데일 카네기 인간관계론
# 조금 서툴더라도 네 인생을 응원해
# 심리학이 조조에게 말하다 1
# 인생의 허무를 어떻게 할 것인가
# 원씽(The One Thing)(리커버 특별판)
# 참 괜찮은 태도
# 이은경쌤의 초등어휘일력 365

# %%
for author in req['data']['bestSeller']:
    print(author['chrcName'])
# Out:
# 김난도 외
# 정지아
# Kohei Horikoshi 외
# 김훈
# 최서영
# 박송이 외
# 김호연
# 김호연
# 리사 제노바 외
# 지나영
# 자청
# 장재형
# Eiichiro Oda
# 데일 카네기 외
# 정은지 외
# 천위안 외
# 김영민
# 게리 켈러 외
# 박지현
# 이은경
